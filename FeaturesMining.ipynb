# %%
import pandas as pd

# %%
df = pd.read_excel("2015.xlsx")
train = df['Response ID'].to_frame()
text = df['Response ID'].to_frame()

# %%
list(df.columns)
# Out:
# ['Response ID',
#  'Time Started',
#  'Date Submitted',
#  'Status',
#  'Contact ID',
#  'Legacy Comments',
#  'Comments',
#  'Language',
#  'Referer',
#  'Extended Referer',
#  'SessionID',
#  'User Agent',
#  'Extended User Agent',
#  'Tags',
#  'IP Address',
#  'Longitude',
#  'Latitude',
#  'Country',
#  'City',
#  'State/Region',
#  'Postal',
#  'Название проекта:Резюме проекта:',
#  'описание, что это такое:Резюме проекта:',
#  'какую задачу решает?:Резюме проекта:',
#  'целевая аудитория:Резюме проекта:',
#  'описание ключевой фишки:Резюме проекта:',
#  ' главный конкурент, предшественник или аналог:Резюме проекта:',
#  'конкурентное преимущество:Резюме проекта:',
#  'Основная идея Вашего проекта',
#  'Дошкольное:Сфера',
#  'Начальная школа 1-4:Сфера',
#  'Средние классы 5-9:Сфера',
#  'Старшие классы 10-11:Сфера',
#  'Высшее образование:Сфера',
#  'Дополнительное образование:Сфера',
#  'Профессиональное развитие:Сфера',
#  'Семейное образование:Сфера',
#  'Иное:Сфера',
# ...

# %%
garbageList = ['Response ID','Time Started','Date Submitted','Status','Contact ID',
 'Legacy Comments','Comments','Language','Referer','Extended Referer','SessionID',
 'User Agent','Extended User Agent','Tags','IP Address', 'Postal',
 'Другое:Что бы Вы хотели получить от Конкурса?.1', 'Ссылки','Опишите преимущества вашей команды и ресурсы, которыми вы располагаете'              
 '1:Email:Члены команды','2:Email:Члены команды','3:Email:Члены команды','4:Email:Члены команды','5:Email:Члены команды',
 '6:Email:Члены команды','7:Email:Члены команды','8:Email:Члены команды','9:Email:Члены команды','10:Email:Члены команды',
 '11:Email:Члены команды','Другое:Кто примет решение об использовании вашей идеи?.1','1:Фамилия :Члены команды',
 '2:Фамилия :Члены команды',
 '3:Фамилия :Члены команды',
 '4:Фамилия :Члены команды',
 '5:Фамилия :Члены команды',
 '6:Фамилия :Члены команды',
 '7:Фамилия :Члены команды',
 '8:Фамилия :Члены команды',
 '9:Фамилия :Члены команды',
 '10:Фамилия :Члены команды',
 '11:Фамилия :Члены команды',
 '1:Имя:Члены команды',
 '2:Имя:Члены команды',
 '3:Имя:Члены команды',
 '4:Имя:Члены команды',
 '5:Имя:Члены команды',
 '6:Имя:Члены команды',
 '7:Имя:Члены команды',
 '8:Имя:Члены команды',
 '9:Имя:Члены команды',
 '10:Имя:Члены команды',
 '11:Имя:Члены команды',
 '1:Роль в команде:Члены команды',
 '2:Роль в команде:Члены команды',
 '3:Роль в команде:Члены команды',
 '4:Роль в команде:Члены команды',
 '5:Роль в команде:Члены команды',
 '6:Роль в команде:Члены команды',
 '7:Роль в команде:Члены команды',
 '8:Роль в команде:Члены команды',
 '9:Роль в команде:Члены команды',
 '10:Роль в команде:Члены команды',
 '11:Роль в команде:Члены команды',]

# %%
#done
textVariables = ['Название проекта:Резюме проекта:',
 'описание, что это такое:Резюме проекта:',
 'какую задачу решает?:Резюме проекта:',
 'целевая аудитория:Резюме проекта:',
 'описание ключевой фишки:Резюме проекта:',
 ' главный конкурент, предшественник или аналог:Резюме проекта:',
 'конкурентное преимущество:Резюме проекта:',
 'Основная идея Вашего проекта']

# %%
#done
trainVariables = ['Longitude','Latitude','Country','City','State/Region']

# %%
#done
innovations =['Продукта или услуги (например, новые программы, пособия, ресурсы):Ваша идея воздействует на образование за счет внедрения новой/нового...',
 'Процессов для предоставления услуг (например, использование ИКТ в обучении):Ваша идея воздействует на образование за счет внедрения новой/нового...',
 'Способов организации деятельности (например, использование ИКТ для коммуникации с учащимися или родителями):Ваша идея воздействует на образование за счет внедрения новой/нового...',
 'Маркетинговых стратегий (например, дифференцированного ценообразования):Ваша идея воздействует на образование за счет внедрения новой/нового...']

# %%
judges = ['Учащиеся:Кто примет решение об использовании вашей идеи?',
 'Педагоги:Кто примет решение об использовании вашей идеи?',
 'Родители:Кто примет решение об использовании вашей идеи?',
 'Директора:Кто примет решение об использовании вашей идеи?',
 'Управленцы:Кто примет решение об использовании вашей идеи?',
 'Предприниматели:Кто примет решение об использовании вашей идеи?',
 'НКО:Кто примет решение об использовании вашей идеи?',
 'Другое:Кто примет решение об использовании вашей идеи?']

# %%
areas =['Экономика и управление образованием:Ваша заявка должна попасть к специалистам в следующих областях',
 'Дополнительное образование и воспитание:Ваша заявка должна попасть к специалистам в следующих областях',
 'Информационные технологии:Ваша заявка должна попасть к специалистам в следующих областях',
 'Игровые и интерактивные технологии:Ваша заявка должна попасть к специалистам в следующих областях',
 'Инженерные науки:Ваша заявка должна попасть к специалистам в следующих областях',
 'Дошкольное образование:Ваша заявка должна попасть к специалистам в следующих областях',
 'Школьное образование:Ваша заявка должна попасть к специалистам в следующих областях',
 'Высшее образование:Ваша заявка должна попасть к специалистам в следующих областях']

# %%
spheres = ['Дошкольное:Сфера',
 'Начальная школа 1-4:Сфера',
 'Средние классы 5-9:Сфера',
 'Старшие классы 10-11:Сфера',
 'Высшее образование:Сфера',
 'Дополнительное образование:Сфера',
 'Профессиональное развитие:Сфера',
 'Семейное образование:Сфера']

# %%
support = ['Инвестиции (коммерческие):Что бы Вы хотели получить от Конкурса?',
 'Инвестиции (благотворительные):Что бы Вы хотели получить от Конкурса?',
 'Поддержку государственных органов:Что бы Вы хотели получить от Конкурса?',
 'Последователей:Что бы Вы хотели получить от Конкурса?',
 'Единомышленников среди инноваторов:Что бы Вы хотели получить от Конкурса?',
 'Экспертизу проекта, консультацию:Что бы Вы хотели получить от Конкурса?',
 'Пиар, помощь в продвижении:Что бы Вы хотели получить от Конкурса?',
 'Менторскую поддержку:Что бы Вы хотели получить от Конкурса?',
 'Другое:Что бы Вы хотели получить от Конкурса?']

# %%
team=[
 '1:Пол:Члены команды',
 '2:Пол:Члены команды',
 '3:Пол:Члены команды',
 '4:Пол:Члены команды',
 '5:Пол:Члены команды',
 '6:Пол:Члены команды',
 '7:Пол:Члены команды',
 '8:Пол:Члены команды',
 '9:Пол:Члены команды',
 '10:Пол:Члены команды',
 '11:Пол:Члены команды',
 '1:Город:Члены команды',
 '2:Город:Члены команды',
 '3:Город:Члены команды',
 '4:Город:Члены команды',
 '5:Город:Члены команды',
 '6:Город:Члены команды',
 '7:Город:Члены команды',
 '8:Город:Члены команды',
 '9:Город:Члены команды',
 '10:Город:Члены команды',
 '11:Город:Члены команды',
 '1:Основное занятие:Члены команды',
 'Другое:1:Основное занятие:Члены команды',
 '2:Основное занятие:Члены команды',
 'Другое:2:Основное занятие:Члены команды',
 '3:Основное занятие:Члены команды',
 'Другое:3:Основное занятие:Члены команды',
 '4:Основное занятие:Члены команды',
 'Другое:4:Основное занятие:Члены команды',
 '5:Основное занятие:Члены команды',
 'Другое:5:Основное занятие:Члены команды',
 '6:Основное занятие:Члены команды',
 'Другое:6:Основное занятие:Члены команды',
 '7:Основное занятие:Члены команды',
 'Другое:7:Основное занятие:Члены команды',
 '8:Основное занятие:Члены команды',
 'Другое:8:Основное занятие:Члены команды',
 '9:Основное занятие:Члены команды',
 'Другое:9:Основное занятие:Члены команды',
 '10:Основное занятие:Члены команды',
 'Другое:10:Основное занятие:Члены команды',
 '11:Основное занятие:Члены команды',
 'Другое:11:Основное занятие:Члены команды',
 '1:Возраст:Члены команды',
 '2:Возраст:Члены команды',
 '3:Возраст:Члены команды',
 '4:Возраст:Члены команды',
 '5:Возраст:Члены команды',
 '6:Возраст:Члены команды',
 '7:Возраст:Члены команды',
 '8:Возраст:Члены команды',
 '9:Возраст:Члены команды',
 '10:Возраст:Члены команды',
 '11:Возраст:Члены команды']

# %%
for var in textVariables:
    text[var]=df[var]
for var in trainVariables:
    train[var]=df[var]

# %%
text=text.rename(index=str, columns={'Название проекта:Резюме проекта:': 'name', 'описание, что это такое:Резюме проекта:': 'desc',
'какую задачу решает?:Резюме проекта:':'aim', 'целевая аудитория:Резюме проекта:': 'audience',
'описание ключевой фишки:Резюме проекта:' : 'killerFeature', ' главный конкурент, предшественник или аналог:Резюме проекта:':'competitors',
'конкурентное преимущество:Резюме проекта:':'advantages',  'Основная идея Вашего проекта' : "idea"})

# %%
text.head()
text.to_csv("texts.csv",index=False)

# %%
l = [judges, innovations, areas, spheres]
for col in l:
    for i in range(len(col)):
        train[col[i]] = list(map(lambda x: 0 if pd.isnull(x) else 1,df[col[i]]))

# %%
train=train.rename(index=str, columns={innovations[0]: 'impactbyProduct', innovations[1]: 'impactbyService',
innovations[2]:'impactbyActivity', innovations[3]: 'impactbyMarketing', })

# %%
judges
judgesExplained = ['desisionStudents', 'decisionTeachers', 'decisionParents', 'decisionHeads', 'decisionManagers',
                  'decisionEnterpreneurs', 'decisionNCO', 'decisionOther']
train = train.rename(index=str, columns = dict(zip(judges,judgesExplained)))

# %%
areas
areasExplained = ['areaEconomics', 'areaNurture', 'areaIT', 'areaGames', 'areaEngineering',
                  'areaPreschool', 'areaSchool', 'areaUniversity']
train = train.rename(index=str, columns = dict(zip(areas,areasExplained)))

# %%
spheres
spheresExplained = ['spherePreschool', 'sphere1-4', 'sphere5-9', 'sphere10-11', 'sphereUniversity',
                  'sphereAdditional', 'sphereProfessional', 'sphereFamily']
train = train.rename(index=str, columns = dict(zip(spheres,spheresExplained)))

# %%
for i in range(len(support)):
    train[support[i]] = list(map(lambda x: 0 if pd.isnull(x) else int(x),df[support[i]]))

# %%
support
supportExplained = ['rewardInvestitionCommercial', 'rewardInvestitionCharitable', 'rewardGovernmentSupport',
                   'rewardFollowers', 'rewardAdherent', 'rewardConsulting', 'rewardPR', 'rewardMentoring', 'rewardOther']
train = train.rename(index=str, columns = dict(zip(support,supportExplained)))

# %%
list(train.columns)
# Out:
# ['Response ID',
#  'Longitude',
#  'Latitude',
#  'Country',
#  'City',
#  'State/Region',
#  'desisionStudents',
#  'decisionTeachers',
#  'decisionParents',
#  'decisionHeads',
#  'decisionManagers',
#  'decisionEnterpreneurs',
#  'decisionNCO',
#  'decisionOther',
#  'impactbyProduct',
#  'impactbyService',
#  'impactbyActivity',
#  'impactbyMarketing',
#  'areaEconomics',
#  'areaNurture',
#  'areaIT',
#  'areaGames',
#  'areaEngineering',
#  'areaPreschool',
#  'areaSchool',
#  'areaUniversity',
#  'spherePreschool',
#  'sphere1-4',
#  'sphere5-9',
#  'sphere10-11',
#  'sphereUniversity',
#  'sphereAdditional',
#  'sphereProfessional',
#  'sphereFamily',
#  'rewardInvestitionCommercial',
#  'rewardInvestitionCharitable',
#  'rewardGovernmentSupport',
#  'rewardFollowers',
#  'rewardAdherent',
#  'rewardConsulting',
#  'rewardPR',
#  'rewardMentoring',
#  'rewardOther']

# %%
train.to_csv("train_woTeams.csv", index=False)
